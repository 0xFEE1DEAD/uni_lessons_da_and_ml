# %%
import numpy as np
import polars as pl
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models import Word2Vec

# %% [markdown]
# # 1. Выбрать dataset с предложениями на русском языке

# %%
df = pl.read_csv(
    "https://github.com/0xFEE1DEAD/tatoeba_rus_to_eng/raw/refs/heads/main/tatoeba_rus_to_eng.tsv",
    separator="\t",
    has_header=False,
    new_columns=["ru_id", "ru", "eng_id", "eng"],
    encoding="utf8",
    quote_char=None,
    ignore_errors=True,
    truncate_ragged_lines=True,
    n_rows=15000,
)

# %%
nlp = spacy.load("ru_core_news_sm")

# %%
def prepare_sentence(sentence: str) -> list[str]:
    """tokenize, transform to lowercase and get lemmas for sentence."""
    prepared_sentence = nlp(sentence)
    return [token.lemma_.lower() for token in prepared_sentence if not token.is_stop and token.is_alpha]


df_with_prepared_tokens = df.with_columns(
    pl.col("ru").map_elements(prepare_sentence, return_dtype=pl.List(pl.String)).alias("tokens"),
).filter(pl.col("tokens").list.len() >= 3)

# %%
df_with_prepared_tokens
# Out:
# shape: (8_909, 5)
# ┌────────┬──────────────────────────┬────────┬──────────────────────────┬──────────────────────────┐
# │ ru_id  ┆ ru                       ┆ eng_id ┆ eng                      ┆ tokens                   │
# │ ---    ┆ ---                      ┆ ---    ┆ ---                      ┆ ---                      │
# │ i64    ┆ str                      ┆ i64    ┆ str                      ┆ list[str]                │
# ╞════════╪══════════════════════════╪════════╪══════════════════════════╪══════════════════════════╡
# │ 243    ┆ Один раз в жизни я делаю ┆ 3257   ┆ For once in my life I'm  ┆ ["раз", "жизнь", …       │
# │        ┆ хорош…                   ┆        ┆ doing …                  ┆ "бесполезны…             │
# │ 5413   ┆ Сегодня 18 июня, и это   ┆ 1280   ┆ Today is June 18th and   ┆ ["сегодня", "июнь", …    │
# │        ┆ день ро…                 ┆        ┆ it is M…                 ┆ "мюриэл"…                │
# │ 5414   ┆ С днём рождения, Мюриэл! ┆ 355041 ┆ Happy birthday, Muiriel! ┆ ["днём", "рождение",     │
# │        ┆                          ┆        ┆                          ┆ "мюриэл"]                │
# │ 5426   ┆ Микрофон по какой-то     ┆ 328546 ┆ For some reason the      ┆ ["микрофон", "причина",  │
# │        ┆ причине д…               ┆        ┆ microphone…              ┆ "работ…                  │
# │ 5429   ┆ Учиться нельзя           ┆ 328883 ┆ Learning should not be   ┆ ["учиться",              │
# │        ┆ заставлять. Учё…         ┆        ┆ forced.…                 ┆ "заставлять", … "п…      │
# │ …      ┆ …                        ┆ …      ┆ …                        ┆ …                        │
# │ 615070 ┆ Как быстро он умеет      ┆ 292312 ┆ How fast he can run!     ┆ ["быстро", "уметь",      │
# │        ┆ бегать!                  ┆        ┆                          ┆ "бегать"]                │
# │ 615393 ┆ Химическая формула воды  ┆ 270773 ┆ The chemical formula for ┆ ["химический",           │
# │        ┆ - H-O-…                  ┆        ┆ water…                   ┆ "формула", … "o…         │
# │ 615398 ┆ Сахара - самая большая в ┆ 54059  ┆ The Sahara is the        ┆ ["сахара", "больший", …  │
# │        ┆ мире …                   ┆        ┆ largest dese…            ┆ "пусты…                  │
# │ 615418 ┆ Все пассажиры погибли в  ┆ 424852 ┆ All the passengers were  ┆ ["пассажир",             │
# │        ┆ аварии…                  ┆        ┆ killed…                  ┆ "погибнуть", "ава…       │
# │ 615474 ┆ Его дом в три раза       ┆ 285695 ┆ His house is three times ┆ ["дом", "три", "раз"]    │
# │        ┆ больше моег…             ┆        ┆ large…                   ┆                          │
# └────────┴──────────────────────────┴────────┴──────────────────────────┴──────────────────────────┘

# %% [markdown]
# Обучите модель TF-IDF и векторизуйте предложения обучающего датасета

# %%
vectorizer = TfidfVectorizer(lowercase=False, preprocessor=lambda x: x, tokenizer=lambda x: x, token_pattern=None)

# %%
tfidf_matrix = vectorizer.fit_transform(df_with_prepared_tokens["tokens"].to_list())

# %% [markdown]
# # Возьмите несколько предложений из тестового датасета и найдите для них топ-3 наиболее близких предложения из обучающего датасета

# %%
for sentence_idx in [3, 6, 9, 15, 30]:
    print("Запрос: " + "=" * 10)
    print(df_with_prepared_tokens[sentence_idx]["ru"].to_list()[0])
    tokens = df_with_prepared_tokens[sentence_idx]["tokens"].to_list()
    query_vec = vectorizer.transform(tokens)
    similarities = cosine_similarity(query_vec, tfidf_matrix).flatten()
    top_3_indices = np.argsort(similarities)[-3:][::-1]
    print("Результат (топ 3): ")
    print(df_with_prepared_tokens[top_3_indices]["ru"].to_list())
    print("=" * 18)
# Out:
# Запрос: ==========
# Микрофон по какой-то причине до этого не работал.
# Результат (топ 3):
# ['Микрофон по какой-то причине до этого не работал.', 'Это была причина, по которой он поступил в университет.', 'Он использует любую причину, чтобы уйти с работы.']
# ==================
# Запрос: ==========
# Я зарабатываю сто евро в день.
# Результат (топ 3):
# ['Я зарабатываю сто евро в день.', 'Я зарабатываю 100 евро в день.', 'Мой муж зарабатывает 100 000 евро в год.']
# ==================
# Запрос: ==========
# Я полагаю, это будет выглядеть несколько иначе, когда ты подумаешь об этом в долгосрочном плане.
# Результат (топ 3):
# ['Я полагаю, это будет выглядеть несколько иначе, когда ты подумаешь об этом в долгосрочном плане.', 'Твой план выглядит лучше моего.', 'Надо полагать, он брат Мэри.']
# ==================
# Запрос: ==========
# Если бы мир не был таким, каков он сейчас, я мог бы доверять людям.
# Результат (топ 3):
# ['Если бы мир не был таким, каков он сейчас, я мог бы доверять людям.', 'Я доверяю Ричарду. Он человек слова.', 'Вам остаётся только доверять друг другу.']
# ==================
# Запрос: ==========
# Если бы я мог послать тебе зефир, Чанг, я сделал бы это.
# Результат (топ 3):
# ['Если бы я мог послать тебе зефир, Чанг, я сделал бы это.', 'Вы бы могли послать это письмо в Японию?', 'Я сказал им послать мне ещё один билет.']
# ==================

# %% [markdown]
# # Word2vec

# %%
def prepare_sentence_word2vec(sentence: str) -> list[str]:
    """tokenize, transform to lowercase."""
    prepared_sentence = nlp(sentence)
    return [token.text.lower() for token in prepared_sentence]


df_with_prepared_tokens_w2v = df.with_columns(
    pl.col("ru").map_elements(prepare_sentence_word2vec, return_dtype=pl.List(pl.String)).alias("tokens"),
).filter(pl.col("tokens").list.len() >= 7)

# %%
df_with_prepared_tokens_w2v
# Out:
# shape: (7_922, 5)
# ┌────────┬──────────────────────────┬─────────┬──────────────────────────┬─────────────────────────┐
# │ ru_id  ┆ ru                       ┆ eng_id  ┆ eng                      ┆ tokens                  │
# │ ---    ┆ ---                      ┆ ---     ┆ ---                      ┆ ---                     │
# │ i64    ┆ str                      ┆ i64     ┆ str                      ┆ list[str]               │
# ╞════════╪══════════════════════════╪═════════╪══════════════════════════╪═════════════════════════╡
# │ 243    ┆ Один раз в жизни я делаю ┆ 3257    ┆ For once in my life I'm  ┆ ["один", "раз", … "."]  │
# │        ┆ хорош…                   ┆         ┆ doing …                  ┆                         │
# │ 5413   ┆ Сегодня 18 июня, и это   ┆ 1280    ┆ Today is June 18th and   ┆ ["сегодня", "18", …     │
# │        ┆ день ро…                 ┆         ┆ it is M…                 ┆ "!"]                    │
# │ 5421   ┆ Не знаю, что и сказать.  ┆ 1288    ┆ I just don't know what   ┆ ["не", "знаю", … "."]   │
# │        ┆                          ┆         ┆ to say.                  ┆                         │
# │ 5425   ┆ Я не знаю, будет ли у    ┆ 531184  ┆ I don't know if I'll     ┆ ["я", "не", … "."]      │
# │        ┆ меня вре…                ┆         ┆ have time…               ┆                         │
# │ 5426   ┆ Микрофон по какой-то     ┆ 328546  ┆ For some reason the      ┆ ["микрофон", "по", …    │
# │        ┆ причине д…               ┆         ┆ microphone…              ┆ "."]                    │
# │ …      ┆ …                        ┆ …       ┆ …                        ┆ …                       │
# │ 614594 ┆ Я отвечу тебе, когда ты  ┆ 1184070 ┆ I'll answer you when     ┆ ["я", "отвечу", … "."]  │
# │        ┆ успоко…                  ┆         ┆ you've ca…               ┆                         │
# │ 615393 ┆ Химическая формула воды  ┆ 270773  ┆ The chemical formula for ┆ ["химическая",          │
# │        ┆ - H-O-…                  ┆         ┆ water…                   ┆ "формула", … "h…        │
# │ 615398 ┆ Сахара - самая большая в ┆ 54059   ┆ The Sahara is the        ┆ ["сахара", "-", … "."]  │
# │        ┆ мире …                   ┆         ┆ largest dese…            ┆                         │
# │ 615409 ┆ Она не только добрая, но ┆ 309988  ┆ She is not only kind but ┆ ["она", "не", … "."]    │
# │        ┆ еще и…                   ┆         ┆ hones…                   ┆                         │
# │ 615474 ┆ Его дом в три раза       ┆ 285695  ┆ His house is three times ┆ ["его", "дом", … "."]   │
# │        ┆ больше моег…             ┆         ┆ large…                   ┆                         │
# └────────┴──────────────────────────┴─────────┴──────────────────────────┴─────────────────────────┘

# %%
w2v_model = Word2Vec(
    sentences=df_with_prepared_tokens_w2v["tokens"].to_list(),
    vector_size=100,
    window=5,
    min_count=3,
    workers=4,
    sg=1,
)

# %%
model = w2v_model.wv

# %%
def sentence_to_vec(tokens: list[str]) -> np.ndarray:
    """Get vectors for tokens."""
    vectors = [model[word] for word in tokens if word in model]
    if not vectors:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

# %%
df_with_prepared_tokens_w2v = df_with_prepared_tokens_w2v.with_columns(
    pl.col("tokens").map_elements(sentence_to_vec, return_dtype=pl.List(pl.Float32)).alias("vectors"),
)

# %%
df_with_prepared_tokens_w2v
# Out:
# shape: (7_922, 6)
# ┌────────┬─────────────────────┬─────────┬─────────────────────┬─────────────────────┬─────────────┐
# │ ru_id  ┆ ru                  ┆ eng_id  ┆ eng                 ┆ tokens              ┆ vectors     │
# │ ---    ┆ ---                 ┆ ---     ┆ ---                 ┆ ---                 ┆ ---         │
# │ i64    ┆ str                 ┆ i64     ┆ str                 ┆ list[str]           ┆ list[f32]   │
# ╞════════╪═════════════════════╪═════════╪═════════════════════╪═════════════════════╪═════════════╡
# │ 243    ┆ Один раз в жизни я  ┆ 3257    ┆ For once in my life ┆ ["один", "раз", …   ┆ [-0.088199, │
# │        ┆ делаю хорош…        ┆         ┆ I'm doing …         ┆ "."]                ┆ 0.171207, … │
# │        ┆                     ┆         ┆                     ┆                     ┆ -0.007…     │
# │ 5413   ┆ Сегодня 18 июня, и  ┆ 1280    ┆ Today is June 18th  ┆ ["сегодня", "18", … ┆ [-0.103766, │
# │        ┆ это день ро…        ┆         ┆ and it is M…        ┆ "!"]                ┆ 0.147823, … │
# │        ┆                     ┆         ┆                     ┆                     ┆ 0.0186…     │
# │ 5421   ┆ Не знаю, что и      ┆ 1288    ┆ I just don't know   ┆ ["не", "знаю", …    ┆ [-0.045393, │
# │        ┆ сказать.            ┆         ┆ what to say.        ┆ "."]                ┆ 0.186346, … │
# │        ┆                     ┆         ┆                     ┆                     ┆ 0.0771…     │
# │ 5425   ┆ Я не знаю, будет ли ┆ 531184  ┆ I don't know if     ┆ ["я", "не", … "."]  ┆ [-0.060721, │
# │        ┆ у меня вре…         ┆         ┆ I'll have time…     ┆                     ┆ 0.116041, … │
# │        ┆                     ┆         ┆                     ┆                     ┆ 0.0391…     │
# │ 5426   ┆ Микрофон по         ┆ 328546  ┆ For some reason the ┆ ["микрофон", "по",  ┆ [0.008423,  │
# │        ┆ какой-то причине д… ┆         ┆ microphone…         ┆ … "."]              ┆ 0.189161, … │
# │        ┆                     ┆         ┆                     ┆                     ┆ 0.02893…    │
# │ …      ┆ …                   ┆ …       ┆ …                   ┆ …                   ┆ …           │
# │ 614594 ┆ Я отвечу тебе,      ┆ 1184070 ┆ I'll answer you     ┆ ["я", "отвечу", …   ┆ [-0.067618, │
# │        ┆ когда ты успоко…    ┆         ┆ when you've ca…     ┆ "."]                ┆ 0.193644, … │
# │        ┆                     ┆         ┆                     ┆                     ┆ 0.0813…     │
# │ 615393 ┆ Химическая формула  ┆ 270773  ┆ The chemical        ┆ ["химическая",      ┆ [0.121887,  │
# │        ┆ воды - H-O-…        ┆         ┆ formula for water…  ┆ "формула", … "h…    ┆ 0.205101, … │
# │        ┆                     ┆         ┆                     ┆                     ┆ -0.0261…    │
# │ 615398 ┆ Сахара - самая      ┆ 54059   ┆ The Sahara is the   ┆ ["сахара", "-", …   ┆ [-0.035681, │
# │        ┆ большая в мире …    ┆         ┆ largest dese…       ┆ "."]                ┆ 0.172305, … │
# │        ┆                     ┆         ┆                     ┆                     ┆ -0.026…     │
# │ 615409 ┆ Она не только       ┆ 309988  ┆ She is not only     ┆ ["она", "не", …     ┆ [-0.053401, │
# │        ┆ добрая, но еще и…   ┆         ┆ kind but hones…     ┆ "."]                ┆ 0.194717, … │
# │        ┆                     ┆         ┆                     ┆                     ┆ 0.0564…     │
# │ 615474 ┆ Его дом в три раза  ┆ 285695  ┆ His house is three  ┆ ["его", "дом", …    ┆ [-0.056441, │
# │        ┆ больше моег…        ┆         ┆ times large…        ┆ "."]                ┆ 0.162961, … │
# │        ┆                     ┆         ┆                     ┆                     ┆ -0.026…     │
# └────────┴─────────────────────┴─────────┴─────────────────────┴─────────────────────┴─────────────┘

# %%
all_vectors = df_with_prepared_tokens_w2v["vectors"].to_list()

for sentence_idx in [3, 6, 9, 15, 30]:
    print("Запрос: " + "=" * 10)
    print(df_with_prepared_tokens_w2v[sentence_idx]["ru"].to_list()[0])
    query_vec = df_with_prepared_tokens_w2v[sentence_idx]["vectors"].to_list()
    similarities = cosine_similarity(query_vec, all_vectors).flatten()
    top_3_indices = np.argsort(similarities)[-3:][::-1]
    print("Результат (топ 3): ")
    print(df_with_prepared_tokens_w2v[top_3_indices]["ru"].to_list())
    print("=" * 18)
# Out:
# Запрос: ==========
# Я не знаю, будет ли у меня время.
# Результат (топ 3):
# ['Я не знаю, будет ли у меня время.', 'Я думаю, у него всё получится.', 'Я не знаю, будет ли у меня время сделать это.']
# ==================
# Запрос: ==========
# Учиться нельзя заставлять. Учёбу нужно поощрять.
# Результат (топ 3):
# ['Учиться нельзя заставлять. Учёбу нужно поощрять.', 'Извините. Беру свои слова обратно.', 'Девочка казалась смущена его грубым вопросом.']
# ==================
# Запрос: ==========
# Я, может, скоро сдамся и вместо этого пойду вздремну.
# Результат (топ 3):
# ['Я, может, скоро сдамся и вместо этого пойду вздремну.', 'Девушку, которая играет в теннис, я знаю.', 'Я читаю только фрагменты новостей в Интернете, но так, общую картину себе представляю.']
# ==================
# Запрос: ==========
# Мне всегда больше нравились таинственные персонажи.
# Результат (топ 3):
# ['Мне всегда больше нравились таинственные персонажи.', 'Лично мне вот этот больше нравится.', 'От этой книги тебе будет больше вреда, чем пользы.']
# ==================
# Запрос: ==========
# Когда я вырасту, я хочу стать королём.
# Результат (топ 3):
# ['Когда я вырасту, я хочу стать королём.', 'Когда я смотрю эту пьесу, я всегда плачу.', 'Пока не забыл, я тебе скажу.']
# ==================
